# %%
# imports

# %matplotlib inline
import numpy as np
import sys
import os
import matplotlib.pyplot as plt
import matplotlib.animation as animation
import matplotlib.colors as colors
from matplotlib.ticker import AutoLocator, MultipleLocator
from mpl_toolkits.mplot3d import Axes3D
import csv

sys.path.append('../../pyVisOS/')
sys.path.append('../')
import osh5def
import osh5io
import osh5vis
import osh5utils

import Plot

# %%
# clear previous diagnostics
os.system('rm -rf MS/ TIMINGS/')

# run osiris simulation
os.system('../../osiris/bin/osiris-2D.e power_test.2d')

# %%
fig, ax = plt.subplots(1, 1, figsize=(12,6), dpi=300, constrained_layout=True)
Plot.Ex(ax, 'e2-000500.h5');

ax.xaxis.set_major_locator(MultipleLocator(100))
ax.yaxis.set_major_locator(MultipleLocator(0.05))

# %%
fig, ax = plt.subplots(1, 1, figsize=(12,6), dpi=300, constrained_layout=True)
Plot.Efft(ax, 'e2-000530.h5');

# %%
fig, ax = plt.subplots(1, 1, figsize=(12,6), dpi=300, constrained_layout=True)
Plot.wigner(ax, 'e2-000000.h5');
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_3307372/3146937598.py in <module>
#       1 fig, ax = plt.subplots(1, 1, figsize=(12,6), dpi=300, constrained_layout=True)
# ----> 2 Plot.wigner(ax, 'e2-000000.h5');
#
# ~/osiris-simulations/1D_raman/../Plot.py in wigner(ax, filename, dir, **kwargspassthrough)
#     344     ts = np.linspace(data.run_attrs.get('XMIN'), data.run_attrs.get('XMAX'), int(data.run_attrs.get('NX')))
#     345     wig = WVD(data.view(np.ndarray), timestamps=ts)
# --> 346     wig.run(True)
#     347     wig.plot(ax=ax, show=False, cmap='turbo', **kwargspassthrough)
#     348     ax.set(xlabel=r'$%s$ $[%s]$' % (data.axes[0].attrs.get('LONG_NAME'), data.axes[0].attrs.get('UNITS')),
#
# TypeError: run() takes 1 positional argument but 2 were given

# %%
# plot phasespace
fig, ax = plt.subplots(1,1, figsize=(7,8), dpi=300)

#Plot.cm_alpha('autumn')
ps_fnms = []
ps_fnms = os.listdir('MS/PHA/x2x1/electrons/')
ps_fnms.sort()
for f in ps_fnms[:]:
    print(f)
    Plot.x(ax, f, cmap='autumn_alpha', colorbar=False, alpha=1)
ax.set(xlim=[-800,1200])

# %%
Plot.movie('MS/FLD/e2/', fps=10, res=2, out_name='w 140.mp4', overlay=True, vmax=0.005, vmin=-0.005, figsize=(7,6), aspect='equal');

# %%
Plot.fft2_movie('MS/FLD/e2/', out_name='n 0-4 FFT f 1.mp4', xlim=[0.4,1.6], ylim=[-0.7,0.7])

# %%
Plot.movie('MS/FLD/e2/', fps=10, res=1, out_name='n 0-4 squared f 01.mp4', overlay=True, f=lambda x:x**2,vmax=5e-6, vmin=0, figsize=(7,6), aspect='equal', cmap='nipy_spectral');

# %%
N = 0.2
w0 = 140
a0 = 0.1
print(N*w0**2*a0**2, '---', 32)

# %% [markdown]
# try a=0.1 (way below), 0.2 (right below), 0.211 (right at limit), 0.3 (right above), 0.4 (way above)
#
# try w0 = 100 (way below), 126.5 (right at limit), 140 (way above)
