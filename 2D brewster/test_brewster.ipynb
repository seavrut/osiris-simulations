# %%
# imports

# %matplotlib inline
import numpy as np
import sys
import os
import matplotlib.pyplot as plt
import matplotlib.animation as animation
import matplotlib.colors as colors
from matplotlib.ticker import AutoLocator, MultipleLocator
from mpl_toolkits.mplot3d import Axes3D
from tftb.processing.cohen import WignerVilleDistribution as WVD

sys.path.append('../../pyVisOS/')
sys.path.append('../')
import osh5def
import osh5io
import osh5vis
import osh5utils

import Plot

# %%
# clear previous diagnostics
os.system('rm -rf MS/ TIMINGS/')

# run osiris simulation
os.system('../../osiris/bin/osiris-2D.e test_brewster.2d')
# Out:
#  Osiris running on host avrutskys-mbp
#  Current working directory = /Users/avrutsky/College/Lab/osiris-simulations/2d plasma short
#  Timer resolution is    2.7000000000000000E-008  seconds
#
#  ***************************************************************
#  *          Using double precision AVX optimized Code          *
#  ***************************************************************
#
#  Software revision: r4f85ea0
#
#
#  Reading input file, full name: simple_plasma_short.2d
#
#  Reading global simulation options...
#  Reading parallel node configuration...
#  Reading grid configuration...
#  cartesian coordinates
#  Reading tstep configuration...
#  Reading restart configuration...
#  Reading g_space configuration...
#  Reading time configuration...
#  Reading emf configuration...
#   - no smoothing specified
#  Reading part configuration...
#  - species (1) configuration...
#     Species name : electrons
#  Reading zpulses ...
#   - Reading zpulse configuration...
#  Reading current configuration...
#   - no smoothing specified
#   - no diagnostics specified
#  Reading antenna configuration...
#   - no antenna array specified
#
#  Initializing simulation:
#   Setting up no_co
#   - Running on 1 processes, 1 thread(s) per process
#   setting up topology
#   Setting up random number seed
#   Setting up grid
#   - setting parallel grid boundaries...
#   Setting up tstep
#   Setting up restart
#   Setting up g_space
#   Setting up time
#   Setting up emf
#   Setting up current
#   Setting up particles
#   Setting up zpulses
#   Setting up antenna array
#   Setting up diagnostics utilities
#
#  Initialization complete!
#
#  Numerical precision :
#  - Fields    : double precision
#  - Particles : double precision
#
#  Global random number generator
#   - Algorithm: Mersenne Twister
#
#  Field Solver:
#  - Standard Yee solver
#  - Guard Cells:
#      x1 : [3, 4]
#      x2 : [3, 4]
#  - Using self generated fields only
#  - No field smoothing
#
#  - Field Boundary condtions:
#      x1 : [Perfectly matched layer, Perfectly matched layer]
#      x2 : [Perfectly matched layer, Perfectly matched layer]
#
# Particles:
# - Number of species: 1
# - Cubic (3rd order) interpolation
# - Using staggered Yee grid values for interpolation
#
#  electrons :
#  - Push at every time step (no subcycling)
#  - SIMD optimized pusher
#
#  Electrical current :
#  - No smoothing done
# Dynamic memory status:
# - Number of allocated memory blocks: 39
# Total Allocated Memory: 1.9 GB
#
#  Starting main simulation loop:
#
# n =          0, t = .000
# n =          1, t = .510
# n =          2, t = 1.020
# n =          3, t = 1.530
# n =          4, t = 2.040
#
#   Simulation completed.
#
#
#  Osiris run completed normally
# 0

# %%
# plot phasespace
# %matplotlib inline
fig, ax = plt.subplots(1,1, figsize=(10,4), dpi=300)

#Plot.Ex(ax1, 'e2-000015.h5')
Plot.x(ax, 'x2x1-electrons-000000.h5', colorbar=True, cmap='autumn', alpha=1.0);
#Plot.x(ax[1], 'x1-electrons-000000.h5');
#Plot.x(ax[2], 'x2-electrons-000000.h5', transpose=True);
ax.grid()
ax.xaxis.set_major_locator(MultipleLocator(500))
ax.xaxis.set_minor_locator(MultipleLocator(100))
ax.yaxis.set_major_locator(MultipleLocator(500))
#ax[1].imshow(data.view(np.ndarray))
#print(data.axes[1].ax) # x1
#ax[2].plot(data.axes[0].ax) # x2

# %%
fig, ax = plt.subplots(dpi=300, figsize=(7,5))
Plot.Ex(ax, 'e2-000000.h5', vmax=0.00001, vmin=-0.00001, xlim=[-1000,1000], ylim=[-250,1000]);

# %%
fig, ax = plt.subplots(dpi=300, figsize=(5,5))
Plot.Efft2(ax, 'e2-000000.h5', xlim=[0.5,1.5], ylim=[-0.5,0.5]);

# %%
Plot.movie('MS/FLD/e2/', 10, 1, 'out n 0-3 one triangle.mp4', True, (7,5), vmin=-0.0005, vmax=0.0005, aspect='equal')
# Out:
# /Users/avrutsky/College/Lab/simulations/2d plasma short/../Plot.py:145: UserWarning: Trying to register the cmap 'autumn_alpha' which already exists.
#   plt.register_cmap(cmap=map_object)
# init()
# init()
# X
# XXXXXXXXXX XXXXXXXXXX XXXXXXXXXX XXXXXXXXXX XXXXXXXXXX X

# %%
data = osh5io.read_h5('e2-000000.h5', 'MS/FLD/e2/')
print(np.argwhere(np.abs(data.axes[0].ax) < 0.5)[0][0])
E = data.view(np.ndarray)[np.argwhere(np.abs(data.axes[0].ax) < 0.5)[0][0]][:2000]

t = data.axes[1].ax[:2000]
fig, ax = plt.subplots(dpi=300, figsize=(10,3))
ax.plot(t, E, linewidth=0.5)

fig, ax = plt.subplots(dpi=100)
wig = WVD(E, timestamps=t)
wig.run(True)
wig.plot(ax=ax, show=False, cmap='turbo')
ax.set(ylim=[0.8,1.2])
# Out:
# 456
# [(0.8, 1.2)]
